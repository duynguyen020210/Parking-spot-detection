# %%
# !pip install scikit-image
# Out:
# Collecting scikit-image
#   Using cached scikit_image-0.20.0-cp310-cp310-win_amd64.whl (23.7 MB)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\appdata\roaming\python\python310\site-packages (from scikit-image) (23.0)
# Collecting imageio>=2.4.1
#   Downloading imageio-2.27.0-py3-none-any.whl (3.4 MB)
#      ---------------------------------------- 0.0/3.4 MB ? eta -:--:--
#       --------------------------------------- 0.1/3.4 MB 1.7 MB/s eta 0:00:03
#      -- ------------------------------------- 0.2/3.4 MB 2.4 MB/s eta 0:00:02
#      ---- ----------------------------------- 0.4/3.4 MB 2.8 MB/s eta 0:00:02
#      ------ --------------------------------- 0.6/3.4 MB 3.3 MB/s eta 0:00:01
#      ------------ --------------------------- 1.1/3.4 MB 4.9 MB/s eta 0:00:01
#      ----------------------- ---------------- 2.0/3.4 MB 7.1 MB/s eta 0:00:01
#      ---------------------------------------  3.4/3.4 MB 10.8 MB/s eta 0:00:01
#      ---------------------------------------- 3.4/3.4 MB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: networkx>=2.8 in c:\users\admin\appdata\roaming\python\python310\site-packages (from scikit-image) (3.0)
# Requirement already satisfied: scipy>=1.8 in c:\users\admin\appdata\roaming\python\python310\site-packages (from scikit-image) (1.10.1)
# Requirement already satisfied: pillow>=9.0.1 in c:\users\admin\appdata\roaming\python\python310\site-packages (from scikit-image) (9.3.0)
# Collecting tifffile>=2019.7.26
#   Using cached tifffile-2023.3.21-py3-none-any.whl (218 kB)
# Collecting PyWavelets>=1.1.1
#   Using cached PyWavelets-1.4.1-cp310-cp310-win_amd64.whl (4.2 MB)
# Collecting lazy_loader>=0.1
#   Using cached lazy_loader-0.2-py3-none-any.whl (8.6 kB)
# Requirement already satisfied: numpy>=1.21.1 in c:\users\admin\appdata\roaming\python\python310\site-packages (from scikit-image) (1.24.2)
# Installing collected packages: tifffile, PyWavelets, lazy_loader, imageio, scikit-image
# Successfully installed PyWavelets-1.4.1 imageio-2.27.0 lazy_loader-0.2 scikit-image-0.20.0 tifffile-2023.3.21

# %%
pip list
# Out:
# Package                      Version
# ---------------------------- ------------
# absl-py                      1.4.0
# anyio                        3.5.0
# argon2-cffi                  21.3.0
# argon2-cffi-bindings         21.2.0
# asttokens                    2.0.5
# attrs                        22.1.0
# Babel                        2.11.0
# backcall                     0.2.0
# beautifulsoup4               4.11.1
# bleach                       4.1.0
# brotlipy                     0.7.0
# certifi                      2022.12.7
# cffi                         1.15.1
# charset-normalizer           2.1.1
# colorama                     0.4.6
# comm                         0.1.2
# comtypes                     1.1.14
# contourpy                    1.0.7
# cryptography                 39.0.1
# cycler                       0.11.0
# debugpy                      1.5.1
# decorator                    5.1.1
# defusedxml                   0.7.1
# distlib                      0.3.6
# entrypoints                  0.4
# executing                    0.8.3
# fastjsonschema               2.16.2
# filelock                     3.9.0
# flatbuffers                  23.3.3
# flit_core                    3.8.0
# fonttools                    4.39.2
# idna                         3.4
# ipykernel                    6.19.2
# ipython                      8.10.0
# ipython-genutils             0.2.0
# ipywidgets                   8.0.4
# jedi                         0.18.1
# Jinja2                       3.1.2
# joblib                       1.2.0
# json5                        0.9.6
# jsonschema                   4.17.3
# jupyter                      1.0.0
# jupyter_client               7.4.9
# jupyter-console              6.6.2
# jupyter_core                 5.2.0
# jupyter-server               1.23.4
# jupyterlab                   3.5.3
# jupyterlab-pygments          0.1.2
# jupyterlab_server            2.19.0
# jupyterlab-widgets           3.0.5
# kiwisolver                   1.4.4
# libclang                     16.0.0
# lxml                         4.9.1
# MarkupSafe                   2.1.2
# matplotlib                   3.7.1
# matplotlib-inline            0.1.6
# mediapipe                    0.9.2.1
# mistune                      0.8.4
# mpmath                       1.2.1
# nbclassic                    0.5.2
# nbclient                     0.5.13
# nbconvert                    6.5.4
# nbformat                     5.7.0
# nest-asyncio                 1.5.6
# networkx                     3.0
# notebook                     6.5.2
# notebook_shim                0.2.2
# numpy                        1.24.2
# oauthlib                     3.2.2
# opencv-contrib-python        4.7.0.72
# opencv-python                4.7.0.72
# packaging                    23.0
# pandas                       1.5.3
# pandocfilters                1.5.0
# parso                        0.8.3
# pickleshare                  0.7.5
# Pillow                       9.3.0
# pip                          23.0.1
# platformdirs                 3.2.0
# ply                          3.11
# prometheus-client            0.14.1
# prompt-toolkit               3.0.36
# protobuf                     3.20.3
# psutil                       5.9.0
# pure-eval                    0.2.2
# pyasn1                       0.4.8
# pyasn1-modules               0.2.8
# pycaw                        20230322
# pycparser                    2.21
# Pygments                     2.11.2
# pyOpenSSL                    23.0.0
# pyparsing                    3.0.9
# PyQt5                        5.15.7
# PyQt5-sip                    12.11.0
# pyrsistent                   0.18.0
# PySocks                      1.7.1
# python-dateutil              2.8.2
# pytz                         2023.2
# pywin32                      305.1
# pywinpty                     2.0.10
# pyzmq                        23.2.0
# qtconsole                    5.4.0
# QtPy                         2.2.0
# requests                     2.28.1
# rsa                          4.9
# scikit-learn                 1.2.2
# scipy                        1.10.1
# Send2Trash                   1.8.0
# setuptools                   65.6.3
# sip                          6.6.2
# six                          1.16.0
# sniffio                      1.2.0
# soupsieve                    2.3.2.post1
# stack-data                   0.2.0
# sympy                        1.11.1
# tensorboard-data-server      0.7.0
# tensorboard-plugin-wit       1.8.1
# tensorflow-estimator         2.12.0
# tensorflow-io-gcs-filesystem 0.31.0
# termcolor                    2.2.0
# terminado                    0.17.1
# threadpoolctl                3.1.0
# tinycss2                     1.2.1
# toml                         0.10.2
# tomli                        2.0.1
# torch                        2.0.0+cu118
# torchaudio                   2.0.1+cu118
# torchvision                  0.15.1+cu118
# tornado                      6.2
# traitlets                    5.7.1
# typing_extensions            4.4.0
# urllib3                      1.26.13
# virtualenv                   20.21.0
# wcwidth                      0.2.5
# webencodings                 0.5.1
# websocket-client             0.58.0
# Werkzeug                     2.2.3
# wheel                        0.38.4
# widgetsnbextension           4.0.5
# win-inet-pton                1.1.0
# wincertstore                 0.2
# wrapt                        1.14.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# cd ./parking-spot-detection
# Out:
# C:\Users\Admin\Desktop\CV\parking-spot-detection

# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import pickle
from skimage.transform import resize

# %%
data_list = os.listdir("./data")
data_paths = []
for data in data_list:
    data_path = os.path.join("./data", data)
    data_paths.append(data_path)
data_paths
# Out:
# ['./data\\mask_1920_1080.png',
#  './data\\mask_crop.png',
#  './data\\parking_1920_1080.mp4',
#  './data\\parking_1920_1080_loop.mp4',
#  './data\\parking_crop.mp4',
#  './data\\parking_crop_loop.mp4']

# %%
EMPTY = True
NOT_EMPTY = False

MODEL = pickle.load(open("car_spot_detection.p", "rb"))

def empty_or_not(spot_bgr):

    flat_data = []

    img_resized = resize(spot_bgr, (15, 15, 3))
    flat_data.append(img_resized.flatten())
    flat_data = np.array(flat_data)

    y_output = MODEL.predict(flat_data)

    if y_output == 0:
        return EMPTY
    else:
        return NOT_EMPTY

# %%
def get_parking_spots_bboxes(connected_components):
    (totalLabels, label_ids, values, centroid) = connected_components

    slots = []
    coef = 1
    for i in range(1, totalLabels):

        # Now extract the coordinate points
        x1 = int(values[i, cv2.CC_STAT_LEFT] * coef)
        y1 = int(values[i, cv2.CC_STAT_TOP] * coef)
        w = int(values[i, cv2.CC_STAT_WIDTH] * coef)
        h = int(values[i, cv2.CC_STAT_HEIGHT] * coef)

        slots.append([x1, y1, w, h])

    return slots

# %%
def calc_diff(img1, img2):
    return np.abs(np.mean(img1) - np.mean(img2))

# %%
mask = cv2.imread(data_paths[0], 0)

cap = cv2.VideoCapture(data_paths[2])

connected_video = cv2.connectedComponentsWithStats(mask, 4, cv2.CV_32S)

spots = get_parking_spots_bboxes(connected_video)
spots_status = [None for _ in spots]

diffs = [None for _ in spots]
previous_frame = None

frame_num = 0
step = 50

while True:
    ret, frame = cap.read()
    
    car_counter = 0
    empty_spot_counter = 0
    
    if frame_num%step == 0 and previous_frame is not None:
        for idx, spot in enumerate(spots):
            x1, y1, w, h = spot
            spot_crop = frame[y1:y1+h, x1:x1+w]
            
            diffs[idx] = calc_diff(spot_crop, previous_frame[y1:y1+h, x1:x1+w])
    
    if frame_num%step == 0:
        if previous_frame is None:
            arr_ = range(len(spots))
        else:
            arr_ = [j for j in np.argsort(diffs) if diffs[j]/np.amax(diffs) > 0.4]
        
        for idx in arr_:
            spot = spots[idx]
            x1, y1, w, h = spot
            spot_crop = frame[y1:y1+h, x1:x1+w]
            spot_status = empty_or_not(spot_crop)
            spots_status[idx] = spot_status
            
           
            
    if frame_num%step == 0:
        previous_frame = frame.copy()
    
    
    for idx, spot in enumerate(spots):  
        spot_status = spots_status[idx]
        x1, y1, w, h = spots[idx]
        
        if spot_status==True:
            cv2.rectangle(frame, (x1,y1), (x1+w,y1+h), (0,0,255), 3)
            empty_spot_counter += 1
        else:
            cv2.rectangle(frame, (x1,y1), (x1+w,y1+h), (255,0,0), 3)
            car_counter += 1
    
    total_spot = car_counter + empty_spot_counter
    
    frame[0:70, 10: 1350] = [0,0,0]
    cv2.putText(frame, f"Car:{car_counter}/{total_spot} - Available spot:{empty_spot_counter}/{total_spot}",
                (25,50), cv2.FONT_HERSHEY_PLAIN, 4, (0,255,0), 4)
    
#         cv2.putText(frame, f"{idx}",(x1,y1+20), cv2.FONT_HERSHEY_PLAIN, 1, (0,255,0), 2)
        
     
    cv2.namedWindow("Video", cv2.WINDOW_NORMAL)   
    cv2.imshow("Video", frame)
    k = cv2.waitKey(10)
    if k == ord("q"):
        break
    frame_num += 1
    
cap.release()
cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()
